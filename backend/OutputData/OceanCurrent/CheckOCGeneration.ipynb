# %%
import numpy as np
import matplotlib.pyplot as plt

RatePower=[2359.958096, 1208.298545, 509.7509487, 151.0373181]

PowerFiles=["PowerTimeSeriesKite_VD50_BCS2.5.npz",
            "PowerTimeSeriesKite_VD50_BCS2.0.npz",
            "PowerTimeSeriesKite_VD50_BCS1.5.npz",
            "PowerTimeSeriesKite_VD50_BCS1.npz"]

plt.hist(np.load(PowerFiles[3])["Energy_pu"].mean(axis=0)*RatePower[3], bins=20)

plt.xlabel("Energy [pu]")
plt.ylabel("# Of Site Locations")
# plt.title("Histogram of Capacity Factor for Design: 50m-2.5m/s")

plt.xlabel("Energy [Kw]")
plt.title("Histogram of Average Power for Design: 50m-1m/s")
# Out:
# Text(0.5, 1.0, 'Histogram of Average Power for Design: 50m-1m/s')
